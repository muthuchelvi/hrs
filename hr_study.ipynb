# %% [markdown]
# <a href="https://colab.research.google.com/github/muthuchelvi/hrs/blob/main/hr_study.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
# !pip install streamlit
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.1/9.1 MB 1.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 36.2 MB/s eta 0:00:00
# ...

# %%
import matplotlib.pyplot as plt

# %%
import streamlit as st

# %%
x = np.array([1, 2, 3, 4])
y = np.array([20, 30, 40, 50])

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(x, y)
# Out:
# LinearRegression()

# %%
x = x.reshape(-1, 1)

# %%
print(model.coef_)
print(model.intercept_)
# Out:
# [10.]
# 10.0

# %%
hours = st.slider("Select hours studied", 0, 10)

# Prediction
if st.button("Predict"):
    pred = model.predict([[hours]])
    st.write("Predicted Marks:", pred[0])

# Plot
fig, ax = plt.subplots()
ax.scatter(x, y)
ax.plot(x, model.predict(x))
st.pyplot(fig)
# Out:
# 2026-03-27 10:16:07.069 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-27 10:16:07.071 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-27 10:16:07.072 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-27 10:16:07.072 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-27 10:16:07.073 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-27 10:16:07.075 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-27 10:16:07.076 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# ...
